# %%
import pickle
import numpy as np

# Загружаем модель из pickle-файла
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# Проверяем, сколько признаков ожидаем модель (через coef_)
print(f"Размер coef_: {model.coef_.shape}")
print(f"Модель ожидаем {len(model.coef_)} признаков")

# Вектор признаков (10 признаков)
features = np.array([[ 0.00538306, -0.04464164,  0.05954058, -0.05616605,  0.02457414, 0.05286081, -0.04340085,  0.05091436, -0.00421986, -0.03007245]])

print(f"Размер входных данных: {features.shape}")

# Делаем предсказание
prediction = model.predict(features)

print(f"Предсказанное значение: {prediction[0]}")
print(f"Округлённое до целого: {round(prediction[0])}")
# Out:
# secret word: skillfactory
# how is this possible? answer is here: https://youtu.be/xm-A-h9QkXg
# Размер coef_: (4,)
# Модель ожидаем 4 признаков
# Размер входных данных: (1, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#      14
#      15 print(f"Размер входных данных: {features.shape}")
#      16
#      17 # Делаем предсказание
# ---> 18 prediction = model.predict(features)
#      19
#      20 print(f"Предсказанное значение: {prediction[0]}")
#      21 print(f"Округлённое до целого: {round(prediction[0])}")
#
# File c:\Users\aleks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:355, in MultiOutputLinearModel.predict(self, X)
#     341 def predict(self, X):
#     342     """
#     343     Predict using the linear model.
#     344
#    (...)    353         Predicted values.
#     354     """
# ...

# %%
import pickle

# Загружаем модель из pickle-файла
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# Проверяем тип модели
print(f"Тип модели: {type(model)}")
print(f"Имя класса модели: {model.__class__.__name__}")
# Out:
# secret word: skillfactory
# how is this possible? answer is here: https://youtu.be/xm-A-h9QkXg
# Тип модели: <class 'sklearn.linear_model._base.LinearRegression'>
# Имя класса модели: LinearRegression
# c:\Users\aleks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.0.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import pickle
import numpy as np

# Загружаем модель из pickle-файла
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# Проверяем тип модели
print(f"Тип модели: {type(model)}")
print(f"Имя класса модели: {model.__class__.__name__}")

# Проверяем, сколько признаков ожидает модель
print(f"Размер coef_: {model.coef_.shape}")
print(f"Модель ожидает {len(model.coef_)} признаков")

# Вектор признаков для задания 3.3
features_3_3 = np.array([[1, 1, 1, 0.661212487096872]])

print(f"\nРазмер входных данных: {features_3_3.shape}")

# Делаем предсказание
prediction_3_3 = model.predict(features_3_3)

print(f"Предсказанное значение: {prediction_3_3[0]}")
print(f"Округлённое до трёх знаков: {round(prediction_3_3[0], 3)}")
# Out:
# secret word: skillfactory
# how is this possible? answer is here: https://youtu.be/xm-A-h9QkXg
# Тип модели: <class 'sklearn.linear_model._base.LinearRegression'>
# Имя класса модели: LinearRegression
# Размер coef_: (4,)
# Модель ожидает 4 признаков
#
# Размер входных данных: (1, 4)
# Предсказанное значение: 0.666
# Округлённое до трёх знаков: 0.666

# %%
import pickle

# Загружаем модель из pickle-файла
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# Извлекаем атрибуты a и b
print(f"model.a = {model.a}")
print(f"model.b = {model.b}")

# Создаём словарь
data_dict = {'a': model.a, 'b': model.b}

# Сохраняем словарь в файл
with open('dict.pkl', 'wb') as f:
    pickle.dump(data_dict, f)

print("\nСловарь сохранён в файл dict.pkl")
# Out:
# secret word: skillfactory
# how is this possible? answer is here: https://youtu.be/xm-A-h9QkXg
# model.a = 5
# model.b = 13
#
# Словарь сохранён в файл dict.pkl
# c:\Users\aleks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.0.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
from nyoka import skl_to_pmml
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)
cols = load_diabetes()['feature_names']

scaler = MinMaxScaler()
pipe = Pipeline([  
            ('Scaling', MinMaxScaler()),
            ('Linear', LinearRegression())
        ])
# Обучение пайплайна, включающего линейную модель и нормализацию признаков
pipe.fit(X, y)
# Сохраним пайплайн в формате pmml в файл pipeline.pmml
skl_to_pmml(pipeline=pipe, col_names=cols, pmml_f_name="pipeline.pmml")

# %%
import onnxruntime as rt 
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from skl2onnx import ___1___
from skl2onnx.common.data_types import ___2___


# загружаем данные
X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)
print(X_train.shape, X_test.shape)

# обучаем модель
model = LinearRegression()
model.fit(___3___, y_train)

# делаем инференс моделью на тесте
test_pred = model.predict(___4___)
print('sklearn model predict:\n', test_pred)

# конвертируем модель в ONNX-формат
initial_type = [('float_input', ___5___([None, ___6___]))]
model_onnx = ___7___(model, initial_types=initial_type)

# сохраняем модель в файл
with open("model.onnx", "wb") as f:
	f.write(model_onnx.SerializeToString())
 	 
# Делаем инференс на тесте через ONNX-runtime
sess = rt.___8___("model.onnx")
input_name = sess.get_inputs()[0].name
label_name = sess.get_outputs()[0].name
test_pred_onnx = sess.run([label_name],
                	{input_name:  X_test.astype(np.float32)})[0].reshape(-1)
print('onnx model predict:\n',test_pred_onnx)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 2
#       1 import onnxruntime as rt
# ----> 2 from sklearn.datasets import load_boston
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.linear_model import LinearRegression
#       5 from skl2onnx import ___1___
#
# File c:\Users\aleks\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\__init__.py:164, in __getattr__(name)
#     113 if name == "load_boston":
#     114     msg = textwrap.dedent(
#     115         """
#     116         `load_boston` has been removed from scikit-learn since version 1.2.
#    (...)    162         """
#     163     )
# --> 164     raise ImportError(msg)
#     165 try:
#     166     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# ...

# %%
from flask import Flask
app = Flask(__name__)

# %%
@app.route('/hello')
def hello_func():
    return 'hello!'

# %%
if __name__ == '__main__':

    app.run('localhost', 5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit

# %%
from server import *

# %%
python -m venv project_a_venv
# Out:
#   Cell In[18], line 1
#     python -m venv project_a_venv
#               ^
# SyntaxError: invalid syntax
