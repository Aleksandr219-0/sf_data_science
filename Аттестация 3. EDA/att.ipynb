# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\aleks\Downloads\new-site\new-site.csv", sep='\t')
df.head()
# Out:
#    site  dwell-time
# 0     0           2
# 1     1          48
# 2     0          15
# 3     1          16
# 4     0          38

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   site        300 non-null    int64
#  1   dwell-time  300 non-null    int64
# dtypes: int64(2)
# memory usage: 4.8 KB

# %%
df.groupby('site')['dwell-time'].sum()
# Out:
# site
# 0    16898
# 1    10032
# Name: dwell-time, dtype: int64

# %%
df.groupby('site')['dwell-time'].mean()
# Out:
# site
# 0    90.849462
# 1    88.000000
# Name: dwell-time, dtype: float64

# %%
from scipy.stats import shapiro

a = shapiro(df[df['site'] == 0]['dwell-time'])
b = shapiro(df[df['site'] == 1]['dwell-time'])

print("A:", a)
print("B:", b)
# Out:
# A: ShapiroResult(statistic=np.float64(0.731232632199737), pvalue=np.float64(4.499873552750829e-17))
# B: ShapiroResult(statistic=np.float64(0.7305351552861856), pvalue=np.float64(3.5727031185288115e-13))

# %%
print(df.columns)
# Out:
# Index(['site', 'dwell-time'], dtype='object')

# %%
print(df['site'].value_counts())
print('A size:', df[df['site'] == 'A'].shape[0])
print('B size:', df[df['site'] == 'B'].shape[0])
# Out:
# site
# 0    186
# 1    114
# Name: count, dtype: int64
# A size: 0
# B size: 0

# %%
from scipy.stats import mannwhitneyu

group_a = df[df['site'] == 0]['dwell-time'].dropna()
group_b = df[df['site'] == 1]['dwell-time'].dropna()

u_stat, p_value = mannwhitneyu(group_a, group_b, alternative='two-sided')

alpha = 0.05

print('U-statistic:', u_stat)
print('p-value:', p_value)

if p_value < alpha:
    print('Время пребывания пользователей на сайте для групп A и B различно. Есть основания полагать, что рекомендательная система увеличивает длительность сессии пользователей.')
else:
    print('Время пребывания пользователей на сайте для групп A и B одинаково. Нет оснований полагать, что рекомендательная система увеличивает длительность сессии пользователей.')
# Out:
# U-statistic: 10506.0
# p-value: 0.895811197131841
# Время пребывания пользователей на сайте для групп A и B одинаково. Нет оснований полагать, что рекомендательная система увеличивает длительность сессии пользователей.
