# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# Загрузка данных
df = pd.read_csv(r"C:\Users\aleks\Downloads\task_data\task_data.csv")

# Удаление столбца SNo
df = df.drop('SNo', axis=1)

# Разделение на признаки и целевую переменную
X = df[['X_1', 'X_2']]
y = df['y']

# SGDClassifier с log_loss (логистическая регрессия)
model = SGDClassifier(loss='log_loss', random_state=42, max_iter=1000, tol=1e-3)
model.fit(X, y)

# Предсказания
y_pred = model.predict(X)

# Матрица ошибок
cm = confusion_matrix(y, y_pred)
print("Матрица ошибок:")
print(cm)

# Подсчёт ошибок: объекты класса 0, предсказанные как класс 1
false_positives = cm[0, 1]
print(f"\nОбъектов класса 0, неверно отнесённых к классу 1: {false_positives}")
# Out:
# Матрица ошибок:
# [[38  2]
#  [12 48]]
#
# Объектов класса 0, неверно отнесённых к классу 1: 2
